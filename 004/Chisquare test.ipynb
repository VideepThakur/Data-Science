# %%
import numpy as np
from scipy.stats import chi2_contingency, chi2

# %%
# Customer satisfaction data
data = np.array([[50, 70],[80, 100],[60, 90],[30, 50],[20, 50]])

print("Observed Frequency Table:")
print(data)
# Out:
# Observed Frequency Table:
# [[ 50  70]
#  [ 80 100]
#  [ 60  90]
#  [ 30  50]
#  [ 20  50]]

# %%
print("Null Hypothesis (H0):")
print("There is no association between device type and customer satisfaction.")

print("\nAlternative Hypothesis (H1):")
print("There is an association between device type and customer satisfaction.")
# Out:
# Null Hypothesis (H0):
# There is no association between device type and customer satisfaction.
#
# Alternative Hypothesis (H1):
# There is an association between device type and customer satisfaction.

# %%
chi_square, p_value, dof, expected = chi2_contingency(data)

print("Chi-Square Statistic =", round(chi_square, 4))
print("Degrees of Freedom =", dof)
print("P-value =", round(p_value, 4))
# print("Expected= ",expected)
# Out:
# Chi-Square Statistic = 5.6382
# Degrees of Freedom = 4
# P-value = 0.2278

# %%
print("Expected Frequencies:\n")

print(expected)
# Out:
# Expected Frequencies:
#
# [[ 48.  72.]
#  [ 72. 108.]
#  [ 60.  90.]
#  [ 32.  48.]
#  [ 28.  42.]]

# %%
alpha = 0.05

critical_value = chi2.ppf(1 - alpha, dof)

print("Critical Value =", round(critical_value, 4))
# Out:
# Critical Value = 9.4877

# %%
if chi_square > critical_value:
    print("Decision: Reject the Null Hypothesis")
else:
    print("Decision: Fail to Reject the Null Hypothesis")
# Out:
# Decision: Fail to Reject the Null Hypothesis

# %%
if p_value < alpha:
    print("Conclusion:")
    print("There is a significant association between device type and customer satisfaction.")
else:
    print("Conclusion:")
    print("There is no significant association between device type and customer satisfaction.")
# Out:
# Conclusion:
# There is no significant association between device type and customer satisfaction.
